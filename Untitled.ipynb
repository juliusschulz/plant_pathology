# %%
from keras.preprocessing.image import ImageDataGenerator
import pandas as pd
import numpy as np 
import os
import imageio
from matplotlib import pyplot as plt
import seaborn as sns
from tqdm import tqdm
import cv2
from sklearn.preprocessing import MinMaxScaler
from keras.applications.mobilenet import preprocess_input
from keras import backend as K
from keras.metrics import categorical_crossentropy
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense,GlobalAveragePooling2D
from keras.applications import MobileNet, imagenet_utils
from keras.applications.mobilenet import preprocess_input
from keras.optimizers import Adam
from keras.layers import Input, Dense, Activation
from keras.utils.np_utils import to_categorical
from keras.models import load_model
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
test = pd.read_csv('test.csv', delimiter=',')
train = pd.read_csv('train.csv', delimiter=',')
train.set_index('image_id', inplace=True)

# %%
K.clear_session()

# %%
X = []
for i in tqdm(range(0,len(train.index))):
    image = imageio.imread(f'train_data/Train_{i}.jpg')
    X.append(image)
X = np.array(X)
y =  train.values
# Out:
# 100%|██████████| 1821/1821 [00:15<00:00, 116.81it/s]

# %%
Xtrain = X[:1450]
ytrain = y[:1450]
Xtest = X[1450:]
ytest = y[1450:]

# %%
plt.imshow(Xtrain[3])

# %%
customised_mobilenet = MobileNet(weights='imagenet', include_top=False, input_shape=(224,224,3))
new_layers = customised_mobilenet.output
new_layers = GlobalAveragePooling2D()(new_layers)
new_layers = Dense(1024, activation='relu')(new_layers)
new_layers = Dense(512, activation='relu')(new_layers)
new_layers = Dense(512, activation='relu')(new_layers)
new_layers = Dense(4, activation='softmax')(new_layers)
new_mobile = Model(inputs=customised_mobilenet.inputs, output=new_layers)
for i, layer in enumerate(new_mobile.layers):
    if i <= 60:
        layer.trainable = False
    else:
        layer.trainable = True
new_mobile.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /Users/juliusschulz/.conda/envs/keras_iters/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`

# %% [markdown]
# # DataGenerator + Fitting

# %%
#datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
#    featurewise_center=True,
#    featurewise_std_normalization=True,
#    rotation_range=20,
#    width_shift_range=0.2,
#    height_shift_range=0.2,
#    horizontal_flip=True)



datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
    featurewise_center=True,
    featurewise_std_normalization=True,
    rescale=1./255,
    rotation_range=15,
    width_shift_range=.15,
    height_shift_range=.15,
    horizontal_flip=True,
    zoom_range = 0.1,)

#training the image preprocessing
datagen.fit(Xtrain, augment=True)
# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
#datagen.fit(Xtrain)

# fits the model on batches with real-time data augmentation:
history = new_mobile.fit_generator(datagen.flow(Xtrain, ytrain, batch_size=32),
                                   validation_data=(Xtest, ytest),
                    steps_per_epoch=len(Xtrain) / 32, epochs=2,)

#new_mobile.save('model.h5')


# evaluate the model
_, train_acc = new_mobile.evaluate(Xtrain, ytrain, verbose=0)
_, test_acc = new_mobile.evaluate(Xtest, ytest, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot history
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/2
# 46/45 [==============================] - 152s 3s/step - loss: 0.4170 - accuracy: 0.8814 - val_loss: 7.4851 - val_accuracy: 0.3881
# Epoch 2/2
# 46/45 [==============================] - 145s 3s/step - loss: 0.4124 - accuracy: 0.8731 - val_loss: 8.3421 - val_accuracy: 0.3450
# Train: 0.330, Test: 0.345

# %%
loaded_model = load_model('model.h5')

# %%
def Scaler(X):
    """Flatten image, scales it, reshapes it"""
    min_max_scaler = MinMaxScaler()
    X = X.reshape(-1,3)
    X = min_max_scaler.fit_transform(X)
    X = X.reshape(224, 224, 3)
    return X

# %%
Xval = []
for i in tqdm(range(0,1821)):
    image = imageio.imread(f'test_data/Test_{i}.jpg')
    image = Scaler(image)
    Xval.append(image)
Xval = np.array(Xval)
# Out:
# 100%|██████████| 1821/1821 [00:30<00:00, 60.26it/s]

# %%
predictions = loaded_model.predict(Xval)
# Out:
# array([[3.5540581e-06, 1.9382658e-04, 9.9980265e-01, 3.5578832e-08],
#        [3.7348826e-04, 3.4334781e-03, 9.9618298e-01, 9.9415329e-06],
#        [9.8241662e-06, 3.5850688e-05, 1.4290171e-08, 9.9995434e-01],
#        ...,
#        [4.0325493e-04, 2.4650505e-02, 9.7479999e-01, 1.4625651e-04],
#        [9.9997103e-01, 5.4671165e-07, 2.8157045e-05, 2.1806144e-07],
#        [9.9983406e-01, 1.4858555e-05, 4.6260277e-05, 1.0475751e-04]],
#       dtype=float32)

# %%
predictions = _

# %%
pd.concat(train predictions
# Out:
# array([[3.5540581e-06, 1.9382658e-04, 9.9980265e-01, 3.5578832e-08],
#        [3.7348826e-04, 3.4334781e-03, 9.9618298e-01, 9.9415329e-06],
#        [9.8241662e-06, 3.5850688e-05, 1.4290171e-08, 9.9995434e-01],
#        ...,
#        [4.0325493e-04, 2.4650505e-02, 9.7479999e-01, 1.4625651e-04],
#        [9.9997103e-01, 5.4671165e-07, 2.8157045e-05, 2.1806144e-07],
#        [9.9983406e-01, 1.4858555e-05, 4.6260277e-05, 1.0475751e-04]],
#       dtype=float32)

# %%
submissiondf = pd.concat([test, pd.DataFrame(predictions, columns=['healthy', 'multiple_diseases', 'rust', 'scab'])], axis=1)

# %%
submissiondf.to_csv('plant_pathology', sep=',', index=False)

# %%
# Out:
# [1.0]
